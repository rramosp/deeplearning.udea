# %% [markdown]
# # LAB 01.03 - Computational Graphs

# %% [markdown]
# ## TASK 01 - Gradient stats
#
# given an nn module plus an input batch, return mean and std of grads of all `named_params` as a dict

# %% [markdown]
# ## TASK 02 - Second order derivative
#
# using `.backward` with `create_graph` set to `True`

# %% [markdown]
# ## TASK 03 - Selective `autograd`
#
#
# using `torch.no_grad()`, create a function that creates a neural network from a spec
#
# neurons = [5,10,20,1], freeze = [True, True, False, False]

# %% [markdown]
# ## TASK 04 - First and second order derivatives in JAX

# %%
import jax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import jax
#
# ModuleNotFoundError: No module named 'jax'
